# %%
! pip3 install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in c:\users\днс\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (1.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\днс\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\днс\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas) (2020.5)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\днс\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas) (1.19.3)
# Requirement already satisfied: six>=1.5 in c:\users\днс\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the 'C:\Users\ДНС\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
Final_pd = pd.read_csv('Финальный датасет.csv')
Final_pd
# Out:
#       Unnamed: 0  stars              name  \
# 0              0      5             Павел
# 1              1      5  Тарабрин Николай
# 2              3      5  Горбатов Николай
# 3              4      5  Горбатов Николай
# 4              5      5              Олег
# ...          ...    ...               ...
# 1654         800      5              Юлия
# 1655         801      5           Татьяна
# 1656         802      1     Захарова  Ира
# 1657         803      3           надежда
# 1658         804      3         Anastasia
#
#                                                feedback  avg_sent gender  \
# 0     Материал плотный  хороший  Очень стильно смотр...  2.666667      M
# 1          Крутая майка  Материал плотный качетсвенный   2.500000      M
# 2                                                   Гуд  1.000000      M
# 3                                                   Гуд  1.000000      M
# 4                     Плотный хлопок  сидит по размеру   5.000000      M
# ...                                                 ...       ...    ...
# 1654                                                 👍🏻  1.000000      F
# 1655        Отличная футболка для сна  Размер в размер   3.500000      F
# 1656  Махровая футболка  есть такие кто захочет тако...  4.666667      F
# 1657       футболка как махровое полотенце  отказалась   5.000000      F
# 1658  По фото не поняла  что футболка сделана из тка...  8.000000      F
#
#       num_words  emoji
# 0             8      0
# 1             5      0
# 2             1      0
# 3             1      0
# 4             5      0
# ...         ...    ...
# 1654          1      1
# 1655          7      0
# 1656         14      0
# 1657          5      0
# 1658         24      0
#
# [1659 rows x 8 columns]

# %%
Final_pd = Final_pd.drop(['Unnamed: 0'], axis=1, inplace=False)

# %%
import os
import re

# %%
import nltk
from nltk.tokenize import word_tokenize, wordpunct_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
nltk.download('stopwords')
from nltk import tokenize
import itertools
from pymorphy2 import MorphAnalyzer
from collections import Counter, defaultdict
import numpy as np
import string
from string import punctuation
from gensim.utils import tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ДНС\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stops = set(stopwords.words('russian') + ["это", "весь","всё", "футболка", "очень"]) # определили список стоп-слов
morph = MorphAnalyzer()

# %%
def normalize(text):
    tokens = re.findall('[а-яёa-z0-9]+', str(text).lower())
    normalized_text = [morph.parse(word)[0].normal_form for word \
                                                            in tokens]
    normalized_text = [word for word in normalized_text if len(word) > 2 and word not in stops]
    
    return normalized_text

# %%
feedback = Final_pd['feedback'].tolist()

# %%
feedback_normalized = [' '.join(normalize(elem)) for elem in feedback]
Final_pd_norm = Final_pd .assign(feedback=feedback_normalized)
Final_pd_norm# нормализовали текст отзыва
# Out:
#       stars              name  \
# 0         5             Павел
# 1         5  Тарабрин Николай
# 2         5  Горбатов Николай
# 3         5  Горбатов Николай
# 4         5              Олег
# ...     ...               ...
# 1654      5              Юлия
# 1655      5           Татьяна
# 1656      1     Захарова  Ира
# 1657      3           надежда
# 1658      3         Anastasia
#
#                                                feedback  avg_sent gender  \
# 0     материал плотный хороший стильно смотреться по...  2.666667      M
# 1             крутой майк материал плотный качетсвенный  2.500000      M
# 2                                                   гуд  1.000000      M
# 3                                                   гуд  1.000000      M
# 4                          плотный хлопок сидеть размер  5.000000      M
# ...                                                 ...       ...    ...
# 1654                                                     1.000000      F
# 1655                         отличный сон размер размер  3.500000      F
# 1656           махровый захотеть носить точно свободный  4.666667      F
# 1657                      махровый полотенце отказаться  5.000000      F
# 1658  фото понять сделать ткань похожий тонкий махро...  8.000000      F
#
#       num_words  emoji
# 0             8      0
# 1             5      0
# 2             1      0
# 3             1      0
# 4             5      0
# ...         ...    ...
# 1654          1      1
# 1655          7      0
# 1656         14      0
# 1657          5      0
# 1658         24      0
#
# [1659 rows x 7 columns]

# %%
Final_pd_norm.to_csv("Финальный датасет норм.csv")

# %%
Final_pd_norm = pd.read_csv('Финальный датасет норм.csv')
Final_pd_norm
# Out:
#       Unnamed: 0  stars              name  \
# 0              0      5             Павел
# 1              1      5  Тарабрин Николай
# 2              2      5  Горбатов Николай
# 3              3      5  Горбатов Николай
# 4              4      5              Олег
# ...          ...    ...               ...
# 1654        1654      5              Юлия
# 1655        1655      5           Татьяна
# 1656        1656      1     Захарова  Ира
# 1657        1657      3           надежда
# 1658        1658      3         Anastasia
#
#                                                feedback  avg_sent gender  \
# 0     материал плотный хороший стильно смотреться по...  2.666667      M
# 1             крутой майк материал плотный качетсвенный  2.500000      M
# 2                                                   гуд  1.000000      M
# 3                                                   гуд  1.000000      M
# 4                          плотный хлопок сидеть размер  5.000000      M
# ...                                                 ...       ...    ...
# 1654                                                NaN  1.000000      F
# 1655                         отличный сон размер размер  3.500000      F
# 1656           махровый захотеть носить точно свободный  4.666667      F
# 1657                      махровый полотенце отказаться  5.000000      F
# 1658  фото понять сделать ткань похожий тонкий махро...  8.000000      F
#
#       num_words  emoji
# 0             8      0
# 1             5      0
# 2             1      0
# 3             1      0
# 4             5      0
# ...         ...    ...
# 1654          1      1
# 1655          7      0
# 1656         14      0
# 1657          5      0
# 1658         24      0
#
# [1659 rows x 8 columns]

# %%
Final_pd_norm = Final_pd_norm.drop(['Unnamed: 0'], axis=1, inplace=False)

# %%
text_list = Final_pd["feedback"].to_list()
text_string = str(text_list)
print("Слов до нормализации:", len(text_string))
text_list_norm = Final_pd_norm["feedback"].to_list()
text_string_norm = str(text_list_norm)
print("Слов после нормализации:",len(text_string_norm))
# Out:
# Слов до нормализации: 84839
# Слов после нормализации: 64441

# %%
Final_F = Final_pd[Final_pd['gender']=="F"]
text_list_F = Final_F ["feedback"].to_list()
text_string_F = str(text_list_F)
print("Слов в женских отзывах до нормализации:", len(text_string_F ))
Final_F_norm = Final_pd_norm[Final_pd_norm['gender']=="F"]
text_list_F_norm = Final_F_norm ["feedback"].to_list()
text_string_F_norm = str(text_list_F_norm)
print("Слов в женских отзывах после нормализации:", len(text_string_F_norm))
Final_M = Final_pd[Final_pd['gender']=="M"]
text_list_M = Final_M ["feedback"].to_list()
text_string_M = str(text_list_M)
print("Слов в мужских отзывах до нормализации:", len(text_string_M))
Final_M_norm = Final_pd_norm[Final_pd_norm['gender']=="M"]
text_list_M_norm = Final_M_norm ["feedback"].to_list()
text_string_M_norm = str(text_list_M_norm)
print("Слов в мужских отзывах после нормализации:", len(text_string_M_norm))
# Out:
# Слов в женских отзывах до нормализации: 48961
# Слов в женских отзывах после нормализации: 37005
# Слов в мужских отзывах до нормализации: 35878
# Слов в мужских отзывах после нормализации: 27436

# %%
import numpy as np
import pandas as pd
# from sklearn.datasets import load_wine
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
labels = '1', '0'
sizes = [35878, 48961]


# Plot
plt.pie(sizes,labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Слов до нормализации')
plt.axis('equal')
plt.show()

# %%
labels = '1', '0'
sizes = [27360, 36968,]


# Plot
plt.pie(sizes,labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Слов после нормализации')
plt.axis('equal')
plt.show()
